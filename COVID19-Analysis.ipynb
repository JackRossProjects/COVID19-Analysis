# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/jack/Desktop/COVID19-Analysis/covid.csv')

# %%
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     01/04/2020    1      4  2020     25       0             Afghanistan
# 1     31/03/2020   31      3  2020     27       0             Afghanistan
# 2     30/03/2020   30      3  2020      8       1             Afghanistan
# 3     29/03/2020   29      3  2020     15       1             Afghanistan
# 4     28/03/2020   28      3  2020     16       1             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 8097  25/03/2020   25      3  2020      0       0                Zimbabwe
# 8098  24/03/2020   24      3  2020      0       1                Zimbabwe
# 8099  23/03/2020   23      3  2020      0       0                Zimbabwe
# 8100  22/03/2020   22      3  2020      1       0                Zimbabwe
# 8101  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
df = df.iloc[::-1]

# %%
sns.scatterplot(data=df, x='month', y='cases')

# %% [markdown]
# <h2>Why is there a gap in the data? Is the data point in December an accident or a real data point?</h2>

# %%
df['year'].unique()
# Out:
# array([2020, 2019])

# %%
_2019 =df[df.year !=2020]

# %%
_2019.cases
# Out:
# 8075    0
# 7925    0
# 7816    0
# 7723    0
# 7505    0
#        ..
# 549     0
# 456     0
# 353     0
# 222     0
# 82      0
# Name: cases, Length: 67, dtype: int64

# %%
cases_2019 = _2019[_2019.cases != 0]

# %%
cases_2019
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 1650  31/12/2019   31     12  2019     27       0                   China
#
#      geoId countryterritoryCode   popData2018
# 1650    CN                  CHN  1.392730e+09

# %% [markdown]
# <h2>It seems that we have 67 datapoints from 2019 but only 1 that contains actual cases of COVID-19 and this was in China on the last day of 2019.</h2>

# %%
_2019.drop([1650])
# Out:
#          dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 8075  31/12/2019   31     12  2019      0       0                   Vietnam
# 7925  31/12/2019   31     12  2019      0       0  United_States_of_America
# 7816  31/12/2019   31     12  2019      0       0            United_Kingdom
# 7723  31/12/2019   31     12  2019      0       0      United_Arab_Emirates
# 7505  31/12/2019   31     12  2019      0       0                  Thailand
# ...          ...  ...    ...   ...    ...     ...                       ...
# 549   31/12/2019   31     12  2019      0       0                   Austria
# 456   31/12/2019   31     12  2019      0       0                 Australia
# 353   31/12/2019   31     12  2019      0       0                   Armenia
# 222   31/12/2019   31     12  2019      0       0                   Algeria
# 82    31/12/2019   31     12  2019      0       0               Afghanistan
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 8101  21/03/2020   21      3  2020      1       0                Zimbabwe
# 8100  22/03/2020   22      3  2020      1       0                Zimbabwe
# 8099  23/03/2020   23      3  2020      0       0                Zimbabwe
# 8098  24/03/2020   24      3  2020      0       1                Zimbabwe
# 8097  25/03/2020   25      3  2020      0       0                Zimbabwe
# ...          ...  ...    ...   ...    ...     ...                     ...
# 4     28/03/2020   28      3  2020     16       1             Afghanistan
# 3     29/03/2020   29      3  2020     15       1             Afghanistan
# 2     30/03/2020   30      3  2020      8       1             Afghanistan
# 1     31/03/2020   31      3  2020     27       0             Afghanistan
# 0     01/04/2020    1      4  2020     25       0             Afghanistan
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
df = df[df.cases | df.deaths != 0]

# %%
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 8101  21/03/2020   21      3  2020      1       0                Zimbabwe
# 8100  22/03/2020   22      3  2020      1       0                Zimbabwe
# 8098  24/03/2020   24      3  2020      0       1                Zimbabwe
# 8096  26/03/2020   26      3  2020      1       0                Zimbabwe
# 8094  28/03/2020   28      3  2020      2       0                Zimbabwe
# ...          ...  ...    ...   ...    ...     ...                     ...
# 4     28/03/2020   28      3  2020     16       1             Afghanistan
# 3     29/03/2020   29      3  2020     15       1             Afghanistan
# 2     30/03/2020   30      3  2020      8       1             Afghanistan
# 1     31/03/2020   31      3  2020     27       0             Afghanistan
# 0     01/04/2020    1      4  2020     25       0             Afghanistan
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
sns.barplot(data=df, x='dateRep', y='deaths')

# %%
USA = df.loc[df['geoId'] == 'US']

# %%
g = sns.barplot(data=USA, x='dateRep', y='cases')
g.set(xticklabels=range(100));

# %%
g = sns.barplot(data=USA, x='dateRep', y='deaths')
g.set(xticklabels=range(100));

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.experimental import enable_iterative_imputer
# now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer

# %%
correlations = df.corr()

corr_heat = sns.heatmap(correlations, cmap="Greens")
plt.title('Feature Correlations');

# %%
(correlations
     .cases
     .drop('cases')
     .sort_values(ascending=True)
     .plot
     .barh(title='Feature Importance Plot',color='red'));
